# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
sheet_id = "1GIxrJps40l_0NfM9N_M95ZFXOjah3UN11djuaERW2Z8"
df = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel("price(US$)")
plt.scatter(df.area,df.price, color = "red",marker = '+')

# %%
import matplotlib.pyplot as plt

# Assuming df, reg, and area are defined properly in your environment

plt.figure(figsize=(10, 6))
plt.scatter(df.area, df.price, color="red", marker='+', label="Data points")
plt.plot(df.area, reg.predict(df[["area"]]), color="blue", label="Linear Regression")
plt.xlabel("Area (sq ft)")
plt.ylabel("Price (US$)")
plt.title("Linear Regression Fit")
plt.legend()
plt.grid(True)
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
predicted_price = reg.predict([[3300]])
print(predicted_price)

# %%
#y = mx +c
m = reg.coef_[0]
c = reg.intercept_

print("y = ", m,"x + ", c)

# %%
area = int(input("What is the price of land you want to know: "))

predicted_price = reg.predict([[area]])

y = m*area + c
print(y)

# %%
sheet_id = "1GIxrJps40l_0NfM9N_M95ZFXOjah3UN11djuaERW2Z8"
df = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv")
df

# %%
p = reg.predict(d[["area"]])  # Predicting prices based on 'area'

# %%
d["prices"] = p
pr)

# %%
New = d.to_csv("prediction.csv",index=False)

# %%
print(NEW)
